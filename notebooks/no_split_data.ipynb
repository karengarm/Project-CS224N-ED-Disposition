# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
ed = pd.read_csv('~/rads_dispo_lim_2023_02_23.csv')
ed.reset_index(inplace=True)
ed.head()
# Out:
#    index           CSN  Rads_order_ID                            Study  \
# 0      0  131290418105      674819827                 XR CHEST 2 VIEWS
# 1      1  131290415760      674821169           CT HEAD WO IV CONTRAST
# 2      2  131290418527      674823260  CT ABDOMEN PELVIS W IV CONTRAST
# 3      3  131290418527      674823261                 XR CHEST 2 VIEWS
# 4      4  131290415760      674823291    XR PELVIS AND HIP 1 VIEW LEFT
#
#                                           Impression              ED_dispo
# 0  1.  Interval increase in perihilar opacities a...  Place in Observation
# 1  1.  No acute intracranial abnormality. 2.  Mil...    Admit to Inpatient
# 2  1.  Multiple loops of dilated small bowel with...    Admit to Inpatient
# 3  1.  Interval increased loculated moderate meta...    Admit to Inpatient
# 4  1.  Redemonstrated fracture of the femoral hea...    Admit to Inpatient

# %%
chexbert_results = pd.read_csv('/root/chexbert_labels.csv')
chexbert_results.reset_index(inplace=True)
# move text column to end so that the csv looks nicer
chexbert_results = chexbert_results[[c for c in chexbert_results if c != 'Report Impression'] + ['Report Impression']]
chexbert_results.head()
# Out:
#    index  Enlarged Cardiomediastinum  Cardiomegaly  Lung Opacity  Lung Lesion  \
# 0      0                         NaN           NaN           1.0          NaN
# 1      1                         NaN           NaN           NaN          NaN
# 2      2                         NaN           NaN           NaN          1.0
# 3      3                         NaN           NaN           NaN          NaN
# 4      4                         NaN           NaN           NaN          NaN
#
#    Edema  Consolidation  Pneumonia  Atelectasis  Pneumothorax  \
# 0    1.0            0.0        NaN          NaN           NaN
# 1    NaN            NaN        NaN          NaN           NaN
# 2    NaN            NaN        NaN          NaN           NaN
# 3    NaN            1.0       -1.0         -1.0           NaN
# 4    NaN            NaN        NaN          NaN           NaN
#
#    Pleural Effusion  Pleural Other  Fracture  Support Devices  No Finding  \
# ...

# %%
ed.to_csv("~/data/ed.csv", index=False)

# %%
chexbert_results.to_csv("~/data/chexbert_results.csv", index=False)
