# %% [markdown]
# - load the results of zero-shot bart predictions on the entire ED dataset
# - use gaussian naive bayes to find optimal threshold, and convert probabilities into labels
#     - use true/false labels instead of entailment/neutral/contradiction
# - write the labels into either a CSV or dataset file (tell Karen)
# - get evaluation metrics like precision, recall, etc.
#     - for accuracy, consider only the positive class

# %%
from transformers import pipeline
import numpy as np
import pandas as pd
from sklearn import metrics
import torch
import datasets
from datasets import Dataset
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

import sys  
sys.path.insert(0, '/root/Project-CS224N-ED-Disposition/')
from scripts import utils
import importlib
importlib.reload(utils)
# Out:
# <module 'scripts.utils' from '/root/Project-CS224N-ED-Disposition/scripts/utils.py'>

# %%
raw_predictions = datasets.load_from_disk("/root/data/zero_shot_predictions/all")
print(raw_predictions)
# print(raw_predictions[0])
# Out:
# Dataset({
#     features: ['sequence', 'labels', 'scores'],
#     num_rows: 146149
# })

# %%
# takes ~1 minute
pdf = utils.zero_shot_results_to_pandas(raw_predictions)
pdf
# Out:
#                                                  sequence  Pneumonia  \
# 0       1.  Interval increase in perihilar opacities a...   0.524612
# 1       1.  No acute intracranial abnormality. 2.  Mil...   0.000776
# 2       1.  Multiple loops of dilated small bowel with...   0.007977
# 3       1.  Interval increased loculated moderate meta...   0.004349
# 4       1.  Redemonstrated fracture of the femoral hea...   0.001767
# ...                                                   ...        ...
# 146144  1.  Acute superior endplate compression deform...   0.018393
# 146145  1.  Diffuse anasarca and mesenteric edema. Pat...   0.259759
# 146146  1.  No ultrasound evidence of deep venous thro...   0.005479
# 146147  1.  Mild fluid overload with new small pleural...   0.937115
# 146148  1.  Distended gallbladder with mild wall thick...   0.005720
#
#         Pneumothorax  Pleural Effusion     Edema  Fracture  Infection  \
# 0           0.118200          0.185744  0.929120  0.009016   0.000204
# 1           0.001084          0.096998  0.106327  0.178153   0.001479
# 2           0.072368          0.182043  0.070339  0.168524   0.018739
# 3           0.008329          0.367867  0.007522  0.025490   0.000482
# 4           0.004236          0.032812  0.011500  0.964834   0.002214
# ...              ...               ...       ...       ...        ...
# 146144      0.060820          0.451436  0.412637  0.755615   0.062306
# 146145      0.308534          0.905350  0.909280  0.350700   0.020335
# 146146      0.008577          0.021521  0.012299  0.011921   0.003024
# 146147      0.457915          0.980537  0.189899  0.097697   0.895856
# 146148      0.018377          0.882999  0.483649  0.014997   0.649261
#
#         Aspiration  Cardiomegaly  Opacities  ...  Small bowel obstruction  \
# 0         0.045569      0.002341   0.920819  ...                 0.000184
# 1         0.086613      0.009535   0.090323  ...                 0.000123
# 2         0.442881      0.045323   0.741595  ...                 0.967760
# 3         0.006146      0.002442   0.441353  ...                 0.000492
# 4         0.136899      0.050998   0.378758  ...                 0.002143
# ...            ...           ...        ...  ...                      ...
# 146144    0.332372      0.260980   0.565540  ...                 0.011410
# 146145    0.230740      0.182957   0.448288  ...                 0.006509
# 146146    0.062111      0.033632   0.033661  ...                 0.000778
# 146147    0.441919      0.020421   0.953561  ...                 0.137809
# 146148    0.044744      0.007654   0.520650  ...                 0.001693
#
#         Pancreatitis  Splenic laceration  Liver laceration   Colitis  \
# 0           0.000046            0.001241          0.000098  0.000074
# 1           0.000875            0.023919          0.000157  0.011096
# 2           0.001242            0.050261          0.004344  0.007286
# 3           0.000209            0.003195          0.000482  0.000569
# 4           0.001374            0.004023          0.000586  0.003734
# ...              ...                 ...               ...       ...
# 146144      0.009234            0.292709          0.014308  0.135798
# 146145      0.002375            0.641667          0.020484  0.012868
# 146146      0.000996            0.030827          0.005801  0.001874
# 146147      0.000449            0.024316          0.001573  0.003006
# 146148      0.000088            0.012831          0.001496  0.000162
#
#         Pyelonephritis  Nephrolithiasis  Malignancy  Pericaridial effusion  \
# 0             0.008013         0.018194    0.000920               0.737004
# 1             0.050141         0.028645    0.003348               0.111382
# 2             0.059447         0.017711    0.960237               0.214792
# 3             0.001479         0.001017    0.219973               0.001170
# 4             0.010466         0.022915    0.014504               0.008745
# ...                ...              ...         ...                    ...
# 146144        0.317787         0.102796    0.059738               0.455190
# 146145        0.124073         0.140058    0.232137               0.229874
# 146146        0.008241         0.035728    0.004741               0.014146
# 146147        0.014492         0.013508    0.003028               0.045328
# 146148        0.002070         0.000573    0.053491               0.350134
#
#         Aortic dissection
# 0                0.000117
# 1                0.000498
# 2                0.003933
# 3                0.000283
# 4                0.001433
# ...                   ...
# 146144           0.036457
# 146145           0.010458
# 146146           0.013719
# 146147           0.003474
# 146148           0.000973
#
# [146149 rows x 32 columns]

# %%
pdf.to_csv('/root/data/zero_shot_predictions/scores.csv')

# %%
chex_df = pd.read_csv('/root/data/chexbert_results.csv')
chex_df.head()
# Out:
#    index  Enlarged Cardiomediastinum  Cardiomegaly  Lung Opacity  Lung Lesion  \
# 0      0                         NaN           NaN           1.0          NaN
# 1      1                         NaN           NaN           NaN          NaN
# 2      2                         NaN           NaN           NaN          1.0
# 3      3                         NaN           NaN           NaN          NaN
# 4      4                         NaN           NaN           NaN          NaN
#
#    Edema  Consolidation  Pneumonia  Atelectasis  Pneumothorax  \
# 0    1.0            0.0        NaN          NaN           NaN
# 1    NaN            NaN        NaN          NaN           NaN
# 2    NaN            NaN        NaN          NaN           NaN
# 3    NaN            1.0       -1.0         -1.0           NaN
# 4    NaN            NaN        NaN          NaN           NaN
#
#    Pleural Effusion  Pleural Other  Fracture  Support Devices  No Finding  \
# 0               NaN            NaN       NaN              NaN         NaN
# 1               NaN            NaN       0.0              NaN         NaN
# 2               1.0            NaN       NaN              NaN         NaN
# 3               1.0            NaN       NaN              NaN         NaN
# 4               NaN            NaN       1.0              NaN         NaN
#
#                                    Report Impression
# 0  1.  Interval increase in perihilar opacities a...
# 1  1.  No acute intracranial abnormality. 2.  Mil...
# 2  1.  Multiple loops of dilated small bowel with...
# 3  1.  Interval increased loculated moderate meta...
# 4  1.  Redemonstrated fracture of the femoral hea...

# %%
# results are very similar to zero_shot_results.ipynb, which only evaluated 30k rows
for label in utils.chex_labels:
    utils.evaluate_naive_bayes(pdf, chex_df, label)
# Out:
# Fracture
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.96    130038
#          1.0       0.64      0.92      0.75     16111
#
#     accuracy                           0.93    146149
#    macro avg       0.81      0.93      0.86    146149
# weighted avg       0.95      0.93      0.94    146149
#
# AUC 0.9265659468920546
# Edema
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.99    139224
#          1.0       0.65      0.88      0.75      6925
#
#     accuracy                           0.97    146149
#    macro avg       0.82      0.93      0.87    146149
# weighted avg       0.98      0.97      0.97    146149
#
# AUC 0.9301084520885337
# Cardiomegaly
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98    143048
#          1.0       0.38      0.60      0.46      3101
#
#     accuracy                           0.97    146149
#    macro avg       0.68      0.79      0.72    146149
# weighted avg       0.98      0.97      0.97    146149
#
# AUC 0.7907185650084355
# Pneumonia
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97    142106
#          1.0       0.26      0.41      0.32      4043
#
#     accuracy                           0.95    146149
#    macro avg       0.62      0.69      0.64    146149
# weighted avg       0.96      0.95      0.96    146149
#
# AUC 0.6893630417615367
# Atelectasis
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98    141417
#          1.0       0.41      0.44      0.42      4732
#
#     accuracy                           0.96    146149
#    macro avg       0.69      0.71      0.70    146149
# weighted avg       0.96      0.96      0.96    146149
#
# AUC 0.7103277078536419
# Pneumothorax
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99    144829
#          1.0       0.24      0.81      0.37      1320
#
#     accuracy                           0.98    146149
#    macro avg       0.62      0.90      0.68    146149
# weighted avg       0.99      0.98      0.98    146149
#
# AUC 0.8950732964706339
# Pleural Effusion
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.97    134443
#          1.0       0.67      0.58      0.62     11706
#
#     accuracy                           0.94    146149
#    macro avg       0.82      0.78      0.80    146149
# weighted avg       0.94      0.94      0.94    146149
#
# AUC 0.7797712980795749

# %%
labels_df = utils.get_labels(pdf, chex_df)
labels_df
# Out:
#                                                  sequence  Pneumonia  \
# 0       1.  Interval increase in perihilar opacities a...      False
# 1       1.  No acute intracranial abnormality. 2.  Mil...      False
# 2       1.  Multiple loops of dilated small bowel with...      False
# 3       1.  Interval increased loculated moderate meta...      False
# 4       1.  Redemonstrated fracture of the femoral hea...      False
# ...                                                   ...        ...
# 146144  1.  Acute superior endplate compression deform...      False
# 146145  1.  Diffuse anasarca and mesenteric edema. Pat...      False
# 146146  1.  No ultrasound evidence of deep venous thro...      False
# 146147  1.  Mild fluid overload with new small pleural...       True
# 146148  1.  Distended gallbladder with mild wall thick...      False
#
#         Pneumothorax  Pleural Effusion  Edema  Fracture  Infection  \
# 0              False             False   True     False      False
# 1              False             False  False     False      False
# 2              False             False  False     False      False
# 3              False             False  False     False      False
# 4              False             False  False      True      False
# ...              ...               ...    ...       ...        ...
# 146144         False             False  False      True      False
# 146145         False              True   True     False      False
# 146146         False             False  False     False      False
# 146147         False              True  False     False       True
# 146148         False              True  False     False       True
#
#         Aspiration  Cardiomegaly  Opacities  ...  Small bowel obstruction  \
# 0            False         False       True  ...                    False
# 1            False         False      False  ...                    False
# 2            False         False       True  ...                     True
# 3            False         False      False  ...                    False
# 4            False         False      False  ...                    False
# ...            ...           ...        ...  ...                      ...
# 146144       False         False       True  ...                    False
# 146145       False         False      False  ...                    False
# 146146       False         False      False  ...                    False
# 146147       False         False       True  ...                    False
# 146148       False         False       True  ...                    False
#
#         Pancreatitis  Splenic laceration  Liver laceration  Colitis  \
# 0              False               False             False    False
# 1              False               False             False    False
# 2              False               False             False    False
# 3              False               False             False    False
# 4              False               False             False    False
# ...              ...                 ...               ...      ...
# 146144         False               False             False    False
# 146145         False                True             False    False
# 146146         False               False             False    False
# 146147         False               False             False    False
# 146148         False               False             False    False
#
#         Pyelonephritis  Nephrolithiasis  Malignancy  Pericaridial effusion  \
# 0                False            False       False                   True
# 1                False            False       False                  False
# 2                False            False        True                  False
# 3                False            False       False                  False
# 4                False            False       False                  False
# ...                ...              ...         ...                    ...
# 146144           False            False       False                  False
# 146145           False            False       False                  False
# 146146           False            False       False                  False
# 146147           False            False       False                  False
# 146148           False            False       False                  False
#
#         Aortic dissection
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 146144              False
# 146145              False
# 146146              False
# 146147              False
# 146148              False
#
# [146149 rows x 32 columns]

# %%
labels_df.to_csv('/root/data/zero_shot_predictions/labels_t50.csv')
